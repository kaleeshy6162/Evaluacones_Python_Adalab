# %% [markdown]
# # Ejercicio Intermedio - Creación de BBDD de películas extraídas de MovieDatabase

# %% [markdown]
# - En este ejercicio vamos a poner en práctica lo que hemos aprendido sobre la **extracción de contenido de APIs** y la **creación de una base de datos** con sus tablas. Siguiendo las fases propuestas, conseguiremos extraer datos de películas y subtítulos, almacenarlos en un DataFrame y finalmente crear una base de datos con la estructura adecuada.

# %% [markdown]
# ## Fase 1: Extracción de datos de películas

# %% [markdown]
# Nuestro primer objetivo es **extraer los datos de películas** de la API de MovieDatabase. Aquí están los detalles:
#
# - Enlace a la API: [MovieDatabase API](https://rapidapi.com/dolphinnoirbusiness/api/moviedatabase8)
# - Endpoint a utilizar: `Random`
# - Datos a extraer:
#   - Título
#   - Año de lanzamiento
#   - Duración (en minutos)
#   - Género (solo el primero)
#   - Contenido para adultos (sí o no)
#   - `id_imdb`
#
#   El objetivo es **extraer 1000 películas** de esta API utilizando el endpoint mencionado.

# %%
import pandas as pd
import requests

# %%
url = "https://moviedatabase8.p.rapidapi.com/Random/1000"

headers = {
	"x-rapidapi-key": "784ba5649fmshc4797be1d2a5e7dp17675ejsnff3cf7a5ea60",
	"x-rapidapi-host": "moviedatabase8.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# [{'_id': '65ef4014675dde8010877c6d',
#   'id': 364242,
#   'title': 'Ladies Club',
#   'vote_average': 5.5,
#   'vote_count': 3,
#   'status': 'Released',
#   'release_date': '1956-04-12T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 90,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0047943',
#   'original_language': 'es',
#   'original_title': 'Club de señoritas',
#   'overview': 'Lonelyhearts advisor on a tv show becomes feminist icon and movement-leader.',
#   'popularity': 1.249,
#   'genres': 'Comedy, Music',
#   'production_companies': 'Cinematográfica Calderón S.A.',
#   'production_countries': 'Mexico',
#   'spoken_languages': 'Spanish'},
#  {'_id': '65ef4401675dde801093f477',
#   'id': 683664,
#   'title': 'XXX Chubby Twats',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2006-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': True,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'XXX Chubby Twats',
#   'overview': 'Straight from the pages of Voluptuous and XL girls comes a collection of thick chicks who are so dirty and nasty, they make the average porn star look like a nun. Sunshine is a reader favorite and her appetite for man sausage and creamy filling is matched by newcomers Devyn Devine and Kitty Lee. Curvy Claire is a busty, slutty English housewife making her American DVD debut. She craves big dick and a messy load and she gets them both. Ava is a sweet faced college student doing her first XXX scene. Roxie is a mature gal with huge hangers who loves a hard pounding.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//Zh9Sjwx8LGVRE31rwSsVig9cOg.jpg',
#   'production_companies': 'Score',
#   'production_countries': 'United States of America'},
#  {'_id': '65ef4021675dde801087a5cb',
#   'id': 230827,
#   'title': 'Albert Dupontel au Tristan Bernard',
#   'vote_average': 7.7,
#   'vote_count': 3,
#   'status': 'Released',
#   'release_date': '1991-10-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'backdrop_path': '/gQHsyZwRqKASsBQMecns0nL0ZWW.jpg',
#   'budget': 0,
#   'original_language': 'fr',
#   'original_title': 'Albert Dupontel au Tristan Bernard',
#   'popularity': 0.93,
#   'poster_path': 'https://image.tmdb.org/t/p/original//92UcSA8eP7grHAqabiTuq448Gic.jpg',
#   'spoken_languages': 'French'},
#  {'_id': '65ef42f0675dde801090abd0',
#   'id': 256544,
#   'title': 'Vampie',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2014-02-14T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 83,
#   'adult': False,
#   'backdrop_path': '/d7SAfrUZERROlE1VF4RLgPnNZeE.jpg',
#   'budget': 0,
#   'imdb_id': 'tt3350528',
#   'original_language': 'en',
#   'original_title': 'Vampie',
#   'overview': 'In this cult film, Azure St. Clair, a neurotic vampiress who is deathly allergic to blood, must protect her only source of food, the VAMPIE (a vampire pie), from a dark vampiric order that wants to use the powers of this deadly pie to revive the dead and enslave the world.',
#   'popularity': 0.641,
#   'poster_path': 'https://image.tmdb.org/t/p/original//uwtnk4lwn5iA596T9z7RphbFthN.jpg',
#   'tagline': 'Eat.',
#   'genres': 'Horror, Comedy',
#   'production_companies': 'wizard entertainment',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef3fab675dde8010865a93',
#   'id': 665754,
#   'title': 'The Big Slime Movie',
#   'vote_average': 8.8,
#   'vote_count': 10,
#   'status': 'Released',
#   'release_date': '2020-02-05T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 80,
#   'adult': False,
#   'backdrop_path': '/dhQ24ZgHwFohdZMsX8HoJijuoFt.jpg',
#   'budget': 0,
#   'imdb_id': 'tt11428638',
#   'original_language': 'nl',
#   'original_title': 'De grote slijmfilm',
#   'overview': 'Indy and Olivia are crazy about making slime, but they run into trouble when a big toy factory boss starts an anti-slime campaign to increase his own toy sales.',
#   'popularity': 1.556,
#   'poster_path': 'https://image.tmdb.org/t/p/original//fXARRAI8UsYoI0pkAGLqy8E8Qnv.jpg',
#   'genres': 'Family, Adventure',
#   'production_companies': 'NewBe',
#   'production_countries': 'Netherlands',
#   'spoken_languages': 'Dutch'},
#  {'_id': '65ef3f86675dde801085fa72',
#   'id': 1115694,
#   'title': 'Goatman',
#   'vote_average': 6.861,
#   'vote_count': 18,
#   'status': 'Released',
#   'release_date': '2023-04-17T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 87,
#   'adult': False,
#   'backdrop_path': '/holtzVB17aoqCJlOiAXhKkCRhqj.jpg',
#   'budget': 20000,
#   'imdb_id': 'tt20770022',
#   'original_language': 'en',
#   'original_title': 'Goatman',
#   'overview': 'A series of grisly murders point to the terrifying cryptid.',
#   'popularity': 197.86,
#   'poster_path': 'https://image.tmdb.org/t/p/original//85N39Re3qw8o52BcmnVlacVPyni.jpg',
#   'genres': 'Horror',
#   'spoken_languages': 'English'},
#  {'_id': '65ef42c6675dde80109031a8',
#   'id': 557679,
#   'title': "Nurses Takin' on Big Dicks",
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2013-06-13T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 102,
#   'adult': True,
#   'budget': 0,
#   'imdb_id': 'tt3005828',
#   'original_language': 'en',
#   'original_title': "Nurses Takin' on Big Dicks",
#   'overview': "Have you been diagnosed terminally horny? Make an appointment with the hottest nurses in XXX! They're busting out of their tight white uniforms to giving you the bedside manner you crave, taking care of the biggest cocks in the biz!",
#   'popularity': 0.844,
#   'poster_path': 'https://image.tmdb.org/t/p/original//dQhAhFtXFfvSfHVVSzn1oHVwkGw.jpg'},
#  {'_id': '65ef43d6675dde8010936b56',
#   'id': 639096,
#   'title': 'La ofensiva final',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1979-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 97,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'es',
#   'original_title': 'La ofensiva final',
#   'popularity': 0.6,
#   'genres': 'Documentary'},
#  {'_id': '65ef42be675dde80109016d7',
#   'id': 569143,
#   'title': "My Dad's Hot Girlfriend 33",
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2016-11-29T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 151,
#   'adult': True,
#   'backdrop_path': '/8i679mh6VSMMmGI3MwnRaWMp5ah.jpg',
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': "My Dad's Hot Girlfriend 33",
#   'overview': "Your dad's girlfriend is young, tight and horny - way hotter than you ever expected. Not only that, she's more interested in you than him! Can you keep a secret? Because when your dad's away, his lusty lady is ready to play, and to make your wildest fantasy come true!",
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//nQRfWbR4yU96WL96LRqgVjS3x7B.jpg',
#   'production_companies': 'Naughty America',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef41aa675dde80108c7bff',
#   'id': 1202876,
#   'title': 'My Friend, The Shadow',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'My Friend, The Shadow',
#   'popularity': 0,
#   'spoken_languages': 'English'},
#  {'_id': '65ef4090675dde801088daa5',
#   'id': 955487,
#   'title': 'NE VV II (Narziss und Echo VideoVersion)',
#   'vote_average': 3,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '1989-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 5,
#   'adult': False,
#   'budget': 0,
#   'homepage': 'http://www.brynntrup.de/filmo/f_31nevv.html',
#   'original_language': 'en',
#   'original_title': 'NE VV II (Narziss und Echo VideoVersion)',
#   'overview': '"Do you really think I give you a chance at me?" - Practice Film for ZDF.',
#   'popularity': 0.6},
#  {'_id': '65ef4368675dde8010920ca0',
#   'id': 777657,
#   'title': 'The Nudity',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2021-07-24T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 80,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt13617896',
#   'original_language': 'ta',
#   'original_title': 'The Nudity',
#   'overview': 'Transwomen consider the Milk Function their most important Ritual. They also celebrate the ritual as their life-time unique festival. So what is the Milk Function? This documentary describes the ritual and explore its celebrations and traditions.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//7itfEmKRX9EOLkgjdjTzTC2gyA9.jpg',
#   'genres': 'Documentary',
#   'production_countries': 'India',
#   'spoken_languages': 'Tamil'},
#  {'_id': '65ef442e675dde80109480f8',
#   'id': 665106,
#   'title': 'Blackberry Smoke -  Homecoming',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2019-11-15T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'backdrop_path': '/1wEBNOjDpsjwPW7WHQvUiSsCf31.jpg',
#   'budget': 0,
#   'original_language': 'de',
#   'original_title': 'Blackberry Smoke -  Homecoming',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//czL91I8WO5OUBTyymNMwV9HICOc.jpg'},
#  {'_id': '65ef3f8d675dde8010860d82',
#   'id': 68865,
#   'title': 'The Amazons',
#   'vote_average': 4.625,
#   'vote_count': 16,
#   'status': 'Released',
#   'release_date': '1973-12-15T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 100,
#   'adult': False,
#   'backdrop_path': '/6LzAI73tDDgLWCmqGFubcUlTcFu.jpg',
#   'budget': 0,
#   'imdb_id': 'tt0070140',
#   'original_language': 'it',
#   'original_title': 'Le guerriere dal seno nudo',
#   'overview': 'Alena Johnston is Antione, the War Goddess of the Amazons, who must mate with the Greek king Theseus to propogate her race. Traditionally this is done only out of duty, but this time she falls in love with her "boy toy"... a definite no-no for an Amazon queen. Helmed by James Bond director Terence Young and based on a story co-authored by Robert Graves, this sexy and spectacular entry in the sword-and-sandal genre features an incredible bevy of Euro-cult starlets including Rosanna Yanni, Helga Line and Luciana Paluzzi, plus a lyrical score by Academy Award-winner Riz Ortolani.',
#   'popularity': 3.599,
#   'poster_path': 'https://image.tmdb.org/t/p/original//zLk6OxYjkQi5003bCmiZAB9vcy2.jpg',
#   'tagline': 'Women Warriors as Sensuous as they are Savage. Women Rulers as Passionate as they are Powerful.',
#   'genres': 'Action, Adventure',
#   'production_companies': 'Films Montana, Les Films La Boétie, Monteluce Film',
#   'production_countries': 'France, Italy, Spain',
#   'spoken_languages': 'Italian'},
#  {'_id': '65ef40bb675dde8010895c2b',
#   'id': 623230,
#   'title': 'Moms Bang Teens 13',
#   'vote_average': 8,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '2015-11-03T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 192,
#   'adult': True,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Moms Bang Teens 13',
#   'overview': 'Mature women teaching teens how to fuck! They sure do know their way around a hard dick!',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//sND3Vxvt8db2Eai1gsQJYXopB9J.jpg',
#   'production_companies': 'Reality Kings',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef40fe675dde80108a291c',
#   'id': 396185,
#   'title': 'Summer in the Lotus Ground',
#   'vote_average': 10,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '2012-01-20T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 60,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Summer in the Lotus Ground',
#   'overview': "A beautiful documentary film set around Dzogchen monastery in Tibet. It focuses on Kjabje Dzogchen Pema Kalsang Rinpoche, who has been instrumental in the rebuilding and re-establishing of the great monastic seat of Dzogchen monastery in Tibet. In 1998 Rinpoche began the construction of the Lotus Ground Retreat Centre in the secluded meadow of Dzogchen Pema Tung. Having completed the stunning Temple of Great Perfection in 2003, he established the Pema Tung annual teachings and empowerments of the secret heart essence of Dzogpa Chenpo for great numbers of fortunate students.  High on the Tibetan plateau, in the hidden valley of Rudam, Kham (Eastern Tibet), is the Buddhist monastery of Tibet. It is home o one of the world's most profound and secret spiritual traditions.",
#   'popularity': 0.6,
#   'tagline': 'Summer in the Lotus Ground',
#   'genres': 'Documentary',
#   'production_companies': 'PBC MUSIC',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef442d675dde8010947cda',
#   'id': 669213,
#   'title': 'Cevapcici',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2005-11-04T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0885401',
#   'original_language': 'de',
#   'original_title': 'Cevapcici',
#   'popularity': 0.6,
#   'production_companies': 'Zweihund, BPitch Control',
#   'production_countries': 'Germany, Switzerland',
#   'spoken_languages': 'No Language'},
#  {'_id': '65ef4116675dde80108a78bc',
#   'id': 739679,
#   'title': 'Manifiesto',
#   'vote_average': 2,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '2019-10-27T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 61,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt10580580',
#   'original_language': 'es',
#   'original_title': 'Manifiesto',
#   'overview': 'Two actors are holed up in a remote house somewhere on the Argentinian coastline. The characters crosses the space-time threshold: Leon Trotsky, in his Mexican exile, asks André Breton to write the first draft of a revolutionary manifesto.',
#   'popularity': 2.829,
#   'poster_path': 'https://image.tmdb.org/t/p/original//pqRPNmqezocgORDK68hPipsRDom.jpg',
#   'genres': 'Documentary, Drama',
#   'production_companies': 'Protón Cine, Puente Films',
#   'production_countries': 'Argentina',
#   'spoken_languages': 'Spanish'},
#  {'_id': '65ef3f44675dde8010855118',
#   'id': 18898,
#   'title': 'Looking for Eric',
#   'vote_average': 6.475,
#   'vote_count': 296,
#   'status': 'Released',
#   'release_date': '2009-05-27T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 119,
#   'adult': False,
#   'backdrop_path': '/zVr1ftXM5SsDex3S7LJSH7zVQBC.jpg',
#   'budget': 0,
#   'homepage': 'http://www.lookingforeric.fr/',
#   'imdb_id': 'tt1242545',
#   'original_language': 'en',
#   'original_title': 'Looking for Eric',
#   'overview': 'A man trying to put his life back on track gets some advice from an unexpected benefactor -- the ex-footballer Eric Cantona.',
#   'popularity': 9.21,
#   'poster_path': 'https://image.tmdb.org/t/p/original//fTHUY0E1FYMFKiQ8UDKx793LtW0.jpg',
#   'tagline': "To win back the love of his life, Eric's going to need a little training.",
#   'genres': 'Comedy, Drama',
#   'production_companies': 'Diaphana Films, Film4 Productions',
#   'production_countries': 'Belgium, France, Italy, Spain, United Kingdom',
#   'spoken_languages': 'French, English'},
#  {'_id': '65ef43b0675dde801092f4a0',
#   'id': 788558,
#   'title': "Today's Chicago Railroads",
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1991-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 112,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': "Today's Chicago Railroads",
#   'overview': "The country's railroading capital, with a network of rail lines unlike anywhere else in the nation. The Fallen Flags of today - Burlington Northern; Chicago & North Western; Chicago Central; Conrail; Grand Trunk Western; Illinois Central; Santa Fe; Soo Line; and Wisconsin Central - were then still independent, operating entities. Other railroads plied the lines there as well: Belt Railway of Chicago; Chicago Rail Link; Chicago Short Line; Chicago, South Shore & South Bend; CSX Transportation; Elgin, Joliet & Eastern; Indiana Harbor Belt; Iowa Interstate; Metra; Norfolk Southern; Union Pacific; and Amtrak.",
#   'popularity': 0.6,
#   'genres': 'Documentary',
#   'production_companies': 'Pentrex'},
#  {'_id': '65ef4311675dde8010910b57',
#   'id': 206106,
#   'title': 'Ident',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2005-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 1,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Ident',
#   'overview': "The animation from which David O'Reilly's logo originates.",
#   'popularity': 0.6,
#   'genres': 'Animation'},
#  {'_id': '65ef436e675dde8010922069',
#   'id': 770690,
#   'title': "Jasper's Close Shave",
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1945-09-28T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0151108',
#   'original_language': 'en',
#   'original_title': "Jasper's Close Shave",
#   'overview': 'A Puppetoon by George Pal.',
#   'popularity': 0.6,
#   'genres': 'Animation',
#   'production_countries': 'United States of America'},
#  {'_id': '65ef3f74675dde801085cccd',
#   'id': 39015,
#   'title': 'Sailor Beware',
#   'vote_average': 6.185,
#   'vote_count': 27,
#   'status': 'Released',
#   'release_date': '1952-02-08T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 108,
#   'adult': False,
#   'backdrop_path': '/ojQ90CIU49QwnEwY9LWpYDaCyjd.jpg',
#   'budget': 0,
#   'imdb_id': 'tt0043989',
#   'original_language': 'en',
#   'original_title': 'Sailor Beware',
#   'overview': "Meeting in a navy recruiting line, Al Crowthers and Melvin Jones become friends. Al has tried to enlist before, but was always rejected. He keeps trying so that he can impress women. Melvin, is allergic to women's cosmetics and his doctor prescribed ocean travel, so he decided to join the navy.",
#   'popularity': 4.745,
#   'poster_path': 'https://image.tmdb.org/t/p/original//fksEN0tiQMbWYwh9Z1OH4fL3yHp.jpg',
#   'tagline': 'They go down to the sea in ships… and come up with oceans of LAUGHTER!',
#   'genres': 'Comedy',
#   'production_companies': 'Paramount, Wallis-Hazen Inc.',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef4065675dde8010885928',
#   'id': 873695,
#   'title': 'Gully Rowdy',
#   'vote_average': 6.5,
#   'vote_count': 2,
#   'status': 'Released',
#   'release_date': '2021-09-17T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 143,
#   'adult': False,
#   'backdrop_path': '/xooyDv4VNgCdjPLWoPy5Uq9V4bn.jpg',
#   'budget': 0,
#   'imdb_id': 'tt13672658',
#   'original_language': 'te',
#   'original_title': 'గల్లీ రౌడీ',
#   'overview': 'A small-time rowdy wants to make it big and fulfil his grandfather’s wish by helping out a professional rowdy with a land issue. A cop takes up a murder case and is on the look-out for the accused.',
#   'popularity': 0.763,
#   'poster_path': 'https://image.tmdb.org/t/p/original//1wOBT6Jvb72eD14CZl7K7sPfd4S.jpg',
#   'genres': 'Comedy, Action',
#   'production_companies': 'Kona Film Corporation, MVV Cinema',
#   'production_countries': 'India',
#   'spoken_languages': 'Telugu'},
#  {'_id': '65ef40fe675dde80108a27c7',
#   'id': 806913,
#   'title': 'La Infinita Distancia',
#   'vote_average': 10,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '2010-03-24T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 97,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt2593212',
#   'original_language': 'es',
#   'original_title': 'La Infinita Distancia',
#   'overview': 'Iván and Marie have relationship problems. Iván leaves Rosario without any explanation. Marie follows him, trying to save the relationship. Between the city and the countryside, the ties that they share make them grow closer and further apart at the same time.',
#   'popularity': 0.6},
#  {'_id': '65ef3fa9675dde8010865703',
#   'id': 123723,
#   'title': 'Gigi',
#   'vote_average': 5.9,
#   'vote_count': 10,
#   'status': 'Released',
#   'release_date': '1949-10-05T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 82,
#   'adult': False,
#   'backdrop_path': '/dJ4xkHC3JLAu5bM6Ax9pjZVKZ70.jpg',
#   'budget': 0,
#   'imdb_id': 'tt0041414',
#   'original_language': 'fr',
#   'original_title': 'Gigi',
#   'overview': "Gilberte is a sixteen year old girl raised by her aunt and grandmother to be a demimondaine. But she's not ready for that yet, and spends her days in lessons and in teasing Mamita's old friend, the rich playboy Gaston LaChaille, and following his affairs from afar. But when Gaston throws off his latest mistress, it looks as if Gigi just might be ready to begin her destined career.",
#   'popularity': 2.795,
#   'poster_path': 'https://image.tmdb.org/t/p/original//devLzCOnSjKKXNZmXxVB8Rd86bA.jpg',
#   'genres': 'Romance, Comedy',
#   'production_companies': 'Codo Cinéma',
#   'production_countries': 'France',
#   'spoken_languages': 'French'},
#  {'_id': '65ef417a675dde80108bd3fd',
#   'id': 988541,
#   'title': '數到十，讓我變成沈曉旭',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2017-03-26T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'backdrop_path': '/lzJGqPkrGYpuSPjv5aEo6RwRDQv.jpg',
#   'budget': 0,
#   'imdb_id': 'tt7323582',
#   'original_language': 'zh',
#   'original_title': '數到十，讓我變成沈曉旭',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//uPylaJv0edWBmAOXRCShAplljBr.jpg',
#   'genres': 'Drama',
#   'production_countries': 'Taiwan',
#   'spoken_languages': 'Mandarin'},
#  {'_id': '65ef3f93675dde8010861ec7',
#   'id': 1009116,
#   'title': 'A Love Story',
#   'vote_average': 7.5,
#   'vote_count': 14,
#   'status': 'Released',
#   'release_date': '2023-04-12T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 91,
#   'adult': False,
#   'backdrop_path': '/ag25pIBv2PCCGFChGOC8QeUNzej.jpg',
#   'budget': 0,
#   'imdb_id': 'tt26597966',
#   'original_language': 'fr',
#   'original_title': "Une histoire d'amour",
#   'overview': "Justine has never dated a woman, and Katia knows her life is hanging by a thread. But when they meet, it's love at first sight. Katia and Justine decide to confront life living a love story, and giving birth to a baby girl, Jeanne. Twelve years later, Justine come to an orderly life and Katia, who kept the child, learn she is doomed. She has to find urgently a guardian for her daughter. Her only option : her brother William, a cynical and desillusioned writer...",
#   'popularity': 3.745,
#   'poster_path': 'https://image.tmdb.org/t/p/original//cF3Uh5F4vybnyamwQxEyslbL6Vd.jpg',
#   'genres': 'Romance, Drama',
#   'production_companies': 'FullDawa Films, Acmé Films',
#   'production_countries': 'France',
#   'spoken_languages': 'French'},
#  {'_id': '65ef4254675dde80108ede2f',
#   'id': 1101220,
#   'title': 'Welcome To Hard Times',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'revenue': 0,
#   'runtime': 5,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Welcome To Hard Times',
#   'overview': 'An old friend returns in need of money',
#   'popularity': 0.6},
#  {'_id': '65ef43c8675dde8010933fa7',
#   'id': 624194,
#   'title': 'Asperger - Nível 1',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2019-08-18T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 18,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'pt',
#   'original_title': 'Asperger - Nível 1',
#   'overview': "Short film about Asperger's disease and how it can affect the life of a carrier and the people around him.",
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//22o6JjXY3xapGqoEe7RZn6Y4yNE.jpg',
#   'genres': 'Drama',
#   'production_countries': 'Brazil',
#   'spoken_languages': 'Portuguese'},
#  {'_id': '65ef4029675dde801087bce2',
#   'id': 135422,
#   'title': 'Terror of Dracula',
#   'vote_average': 1,
#   'vote_count': 3,
#   'status': 'Released',
#   'release_date': '2012-03-10T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 99,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt2325991',
#   'original_language': 'en',
#   'original_title': 'Terror of Dracula',
#   'overview': "When Jonathan Harker, a young solicitor from England travels into the heart of the Carpathian mountains to meet with the ancient Count Dracula, he discovers the bloody terror and plague that now threatens to cast its shadow over England! Meanwhile, Quincy Morris summons his old friend Professor Van Helsing when a mysterious illness consumes his wife. Are the two puncture wounds on Lucy's throat the work of a vampire? It's a race against time as our heroes fight to save the souls of their beloved from the clutches of the original screen terror...THE TERROR OF DRACULA!",
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//yYCNkC5nNMxiYgc4VFWxMEaXUcD.jpg',
#   'genres': 'Horror'},
#  {'_id': '65ef40e3675dde801089d34b',
#   'id': 408006,
#   'title': 'Passage secret',
#   'vote_average': 5,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '1985-07-24T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 85,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0089781',
#   'original_language': 'en',
#   'original_title': 'Passage secret',
#   'overview': 'In a somewhat deflated story of robbery and deception set against the rooftops and byways of Paris, a group of enterprising petty thieves take advantage of the dog days of August to burglarize vacated apartments. At this time of year, all Parisiens are on vacation elsewhere, and the city is invaded by tourists on vacation from their own cities. In this mass rearrangement of the European population, the thieves get away with their looting until they run into an architect who catches them in the act. But his morals are nothing to brag about, as he gets more involved in what they are doing and wants some of their take. He is also smitten with one of the down-and-out women the thieves have been supporting (Dominque Laffin). As in so many French dramas, these conflicting relationships are doomed to be resolved only by tragedy.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//4nBHYWdbKAs1ZDy5OCcOKqwkIDS.jpg'},
#  {'_id': '65ef41c2675dde80108ccf94',
#   'id': 1160058,
#   'title': 'A Girl Knows 5',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2016-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': True,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'A Girl Knows 5',
#   'overview': 'Here you will find 5 hot scenes with young and filthy girls pampering themselves uninhibited according to all the rules of the art!',
#   'popularity': 0,
#   'poster_path': 'https://image.tmdb.org/t/p/original//4LBK4rFPuZ4YgOm7s4hlIyJq1bO.jpg',
#   'production_companies': '#LetsDoeit'},
#  {'_id': '65ef40e8675dde801089e44a',
#   'id': 778619,
#   'title': "WCCW Parade of Champions '85",
#   'vote_average': 7,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '1985-05-05T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 90,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': "WCCW Parade of Champions '85",
#   'overview': 'The second annual David Von Erich Memorial Parade of Champions held at Texas Stadium in Irving, Texas',
#   'popularity': 0.6,
#   'production_companies': 'World Class Championship Wrestling',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef42a5675dde80108fd5d8',
#   'id': 431610,
#   'title': "Love & Loyalty: The Making of 'The Remains of the Day'",
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2001-10-22T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 28,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0451105',
#   'original_language': 'en',
#   'original_title': "Love & Loyalty: The Making of 'The Remains of the Day'",
#   'overview': 'The filmmakers and lead actors of The Remains of the Day (1993) discuss how they came to make the film, and the subtle power of its execution.',
#   'popularity': 2.737,
#   'poster_path': 'https://image.tmdb.org/t/p/original//n7i2vCmapCJFPI7seqTj13lPAYN.jpg',
#   'genres': 'Documentary',
#   'spoken_languages': 'English'},
#  {'_id': '65ef4397675dde801092a2d7',
#   'id': 820178,
#   'title': 'Šaty dělají člověka',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1913-02-21T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0002474',
#   'original_language': 'cs',
#   'original_title': 'Šaty dělají člověka',
#   'popularity': 0.6,
#   'genres': 'Comedy',
#   'production_companies': 'ASUM',
#   'spoken_languages': 'No Language'},
#  {'_id': '65ef4009675dde8010875f5a',
#   'id': 505090,
#   'title': 'The Taste of Love',
#   'vote_average': 8.5,
#   'vote_count': 4,
#   'status': 'Released',
#   'release_date': '2018-02-14T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 73,
#   'adult': False,
#   'backdrop_path': '/gQixTwzJIj0adYNSflSv5gmPwez.jpg',
#   'budget': 0,
#   'homepage': 'https://www.thetasteoflove.gr',
#   'imdb_id': 'tt8069260',
#   'original_language': 'el',
#   'original_title': 'Η Γεύση της Αγάπης',
#   'overview': 'Aris, a lonely 48-year-old man, lives with a young beautiful girl who anticipates and fulfills all his desires without asking for anything in return, since she is a robot and the year is 2038. ELLi has a perfect human form, the most advanced artificial intelligence, and access to all the data of Aris in the Cloud, acting as the ideal personal assistant. Until its operational system is upgraded with Artificial Emotions - and now, feeling neglected, it demands to learn what love is.',
#   'popularity': 1.104,
#   'poster_path': 'https://image.tmdb.org/t/p/original//aAxBrZLh5mxXtFRRCekHtZRx997.jpg',
#   'genres': 'Romance, Science Fiction',
#   'production_companies': 'Foss Productions',
#   'production_countries': 'Greece',
#   'spoken_languages': 'Greek'},
#  {'_id': '65ef4400675dde801093f16c',
#   'id': 682824,
#   'title': '50/50 SOLA AOI',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2002-12-27T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 60,
#   'adult': True,
#   'budget': 0,
#   'original_language': 'ja',
#   'original_title': '50/50 SOLA AOI',
#   'overview': 'Sora cohabiting in a luxurious room with her lover who she has has been dating for 7 years but never made love to. They have a hard time paying the rent, so she begins to work in the cabaret club ...',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//4GbZ4Tx6WuQKhptcAlLflnxAKhi.jpg',
#   'production_companies': 'Alice Japan',
#   'production_countries': 'Japan',
#   'spoken_languages': 'Japanese'},
#  {'_id': '65ef3fc6675dde801086a107',
#   'id': 232186,
#   'title': 'Ein Mann geht durch die Wand',
#   'vote_average': 6.7,
#   'vote_count': 7,
#   'status': 'Released',
#   'release_date': '1959-10-14T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0053047',
#   'original_language': 'de',
#   'original_title': 'Ein Mann geht durch die Wand',
#   'overview': 'Mr. Buchsbaum, third class taxes employee, lives a peaceful life until the new chief immediately criticizes his work. His only confort is his stamps collection. Sadly, even this consolation and his peace are threatened by a new, charming, neighbour who teaches piano.  Increasingly infuriated, he discovers accidentally one evening that he has the ability to go through walls. With this power, he decides to settle the scores, firstly with his boss who downgraded him.',
#   'popularity': 2.101,
#   'poster_path': 'https://image.tmdb.org/t/p/original//naGj2FbC0BZXGQWRojAuPRFzouV.jpg',
#   'genres': 'Comedy',
#   'production_countries': 'Germany',
#   'spoken_languages': 'German, Russian'},
#  {'_id': '65ef43a6675dde801092d1c3',
#   'id': 843495,
#   'title': 'Lairs',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2021-06-15T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 2,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt12667090',
#   'original_language': 'en',
#   'original_title': 'Lairs',
#   'overview': "Lairs, layers, liars: In this poetry film, hatred insidiously supplants a couple's love.",
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//haNHEiGQrbxvRe1zYwiT3pVVnnY.jpg',
#   'genres': 'Animation',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef410f675dde80108a60d4',
#   'id': 848761,
#   'title': 'Levi: Becoming Himself',
#   'vote_average': 2,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '2021-07-16T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt13220544',
#   'original_language': 'en',
#   'original_title': 'Levi: Becoming Himself',
#   'overview': "A documentary that is the journey of adopted identical Vietnamese twins. At a tender age, one of the twins begins to navigate their gender identity and the family pulls together to support Levi's transition.",
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//qMIo7BLwx086DSPEcXwsSzx0JI4.jpg',
#   'genres': 'Documentary',
#   'production_countries': 'Canada'},
#  {'_id': '65ef411b675dde80108a86f2',
#   'id': 858651,
#   'title': 'Iliazd',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2021-07-20T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 90,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'ru',
#   'original_title': 'Ильязд',
#   'overview': 'Dadaist poet, Russian and cosmopolitan artist, creator and publisher of some of the most beautiful books of the 20th century, Ilia Zdanevitch, aka Iliazd, is a little-known but major figure of modern art. Almost half a century after his death, Ilia, a young Russian agitator, sets out on his trail.',
#   'popularity': 0.668,
#   'poster_path': 'https://image.tmdb.org/t/p/original//AdZOnzZKUT0P6vHVeDHdc4s2UlK.jpg',
#   'genres': 'Drama',
#   'production_companies': 'Lyncae, Feedback Studio, Perspective Films, Kosmosfilm, Objet Direct',
#   'production_countries': 'Russia, France',
#   'spoken_languages': 'French, Russian'},
#  {'_id': '65ef3f90675dde8010861809',
#   'id': 237143,
#   'title': 'Apocrypha',
#   'vote_average': 4.933,
#   'vote_count': 15,
#   'status': 'Released',
#   'release_date': '2009-07-22T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 13,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt1790638',
#   'original_language': 'en',
#   'original_title': 'Apocrypha',
#   'overview': "A young boy picks up his father's camera, with which he accidentally films a dying romance between a man and a woman-",
#   'popularity': 1.443,
#   'poster_path': 'https://image.tmdb.org/t/p/original//iZDD11VEu5cMIhvjptTYOLjedFO.jpg',
#   'genres': 'Drama'},
#  {'_id': '65ef4091675dde801088de22',
#   'id': 458687,
#   'title': 'The Magic Behind the Cape',
#   'vote_average': 7,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '2001-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 24,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0371805',
#   'original_language': 'en',
#   'original_title': 'The Magic Behind the Cape',
#   'overview': 'The story of the development of the visual effects used in the first Christopher Reeve Superman film.',
#   'popularity': 0.6,
#   'genres': 'Documentary',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef42e9675dde80109098de',
#   'id': 268756,
#   'title': 'N.A.S.A.: The Spirit of Apollo',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2012-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 109,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt1733234',
#   'original_language': 'en',
#   'original_title': 'N.A.S.A.: The Spirit of Apollo',
#   'overview': "A look behind the making of N.A.S.A.'s globetrotting debut album 'The Spirit of Apollo,' featuring footage of (to name a few) George Clinton's consciousness altered session, Method Man performing magic tricks, and recording Sizzla and Amanda Blank in Judgement Yard, Jamaica",
#   'popularity': 0.6,
#   'production_companies': 'Squeak E. Clean Productions',
#   'production_countries': 'United States of America'},
#  {'_id': '65ef4330675dde8010916d32',
#   'id': 390798,
#   'title': 'Slayer: [1983] Costa Mesa, CA',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1983-12-28T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Slayer: [1983] Costa Mesa, CA',
#   'overview': 'Slayer at The Concert Factory, Costa Mesa, CA, USA  Halloween  Evil Has No Boundaries  Aggressive Perfector  Crionics  The Final Command  The Antichrist  Black Magic  Die by the Sword  Fight Till Death  Show No Mercy',
#   'popularity': 0.6},
#  {'_id': '65ef40df675dde801089cce8',
#   'id': 337801,
#   'title': 'Devil Goddess',
#   'vote_average': 5,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '1955-10-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 70,
#   'adult': False,
#   'backdrop_path': '/7FPkYV210TyOJ8RU41qTq2JjHnS.jpg',
#   'budget': 0,
#   'imdb_id': 'tt0047991',
#   'original_language': 'en',
#   'original_title': 'Devil Goddess',
#   'overview': 'Jungle-Jim type Johnny Weissmuller helps Professor Blakely look for a missing colleague who is now playing "god" for a bunch of natives.',
#   'popularity': 1.234,
#   'poster_path': 'https://image.tmdb.org/t/p/original//10kEjIvYzG81oV4AiMboqpGjHrk.jpg',
#   'tagline': 'Thundering With Jungle Adventure... Throbbing With Jungle Thrills!',
#   'genres': 'Adventure',
#   'production_companies': 'Clover Productions',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef3f7d675dde801085e4ec',
#   'id': 118316,
#   'title': 'Stop! Look! and Hasten!',
#   'vote_average': 6.6,
#   'vote_count': 22,
#   'status': 'Released',
#   'release_date': '1954-08-13T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 7,
#   'adult': False,
#   'backdrop_path': '/8lcb8E7UsEtcnQ827VoTTqktqbc.jpg',
#   'budget': 0,
#   'imdb_id': 'tt0047526',
#   'original_language': 'en',
#   'original_title': 'Stop! Look! and Hasten!',
#   'overview': "A Burmese tiger trap, a pop-up steel wall, a motorcycle, and a box of Acme-brand leg-building vitamins can't help the Coyote (Eatibus anythingus) catch the Road Runner (Hot Rodicus supersonicus).",
#   'popularity': 2.899,
#   'poster_path': 'https://image.tmdb.org/t/p/original//sBTTwzJdGMH25snjShOp4hB26NL.jpg',
#   'genres': 'Animation',
#   'production_companies': 'Warner Bros. Pictures, Warner Bros. Cartoons',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef406e675dde80108874be',
#   'id': 799991,
#   'title': 'A1 Express',
#   'vote_average': 4.5,
#   'vote_count': 2,
#   'status': 'Released',
#   'release_date': '2021-03-05T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 130,
#   'adult': False,
#   'backdrop_path': '/txk9wEsk7JH3EiAAyrsLBhKtQy1.jpg',
#   'budget': 0,
#   'imdb_id': 'tt11214972',
#   'original_language': 'te',
#   'original_title': 'A1 ఎక్స్\u200cప్రెస్',
#   'overview': 'The Yanam hockey team is fighting hard to save their stadium from a corrupt Sports Minister. Will they win the match that decides their fate?',
#   'popularity': 2.019,
#   'poster_path': 'https://image.tmdb.org/t/p/original//2WHx9ryr1XigcqCudVJfA4IK0jC.jpg',
#   'genres': 'Drama, Family',
#   'production_companies': 'People Media Factory, Venkatadri Talkies',
#   'production_countries': 'India',
#   'spoken_languages': 'Telugu'},
#  {'_id': '65ef3fd7675dde801086d099',
#   'id': 454963,
#   'title': 'Conspiracy Theory',
#   'vote_average': 2.5,
#   'vote_count': 6,
#   'status': 'Released',
#   'release_date': '2016-01-29T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 79,
#   'adult': False,
#   'backdrop_path': '/nQjWBknlxJlow1vCqrUTV4Pq7gs.jpg',
#   'budget': 300,
#   'imdb_id': 'tt5354458',
#   'original_language': 'en',
#   'original_title': 'Conspiracy Theory',
#   'overview': 'A television crew heads to Nevada to search for alien life.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//zdfuTAysvXQRGwd8LKilbRzFj7O.jpg',
#   'tagline': 'One Man Will Discover Our Darkest Secrets',
#   'genres': 'Horror, Science Fiction, Thriller',
#   'production_companies': 'Team Octagon',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef4317675dde8010911d8a',
#   'id': 155139,
#   'title': 'The Patron Saints',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2013-01-11T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 72,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt2044046',
#   'original_language': 'en',
#   'original_title': 'The Patron Saints',
#   'overview': "A home for the aged's youngest resident narrates a documentary about his new home.",
#   'popularity': 0.6,
#   'genres': 'Documentary',
#   'production_countries': 'Canada, United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef43e4675dde80109398c8',
#   'id': 586110,
#   'title': 'Red Card',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2014-06-02T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 3,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt7059710',
#   'original_language': 'en',
#   'original_title': 'Red Card',
#   'overview': 'A woman is making dinner in the kitchen, which disturbs her husband who is watching TV.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//iKCkbRsO8s7x7njCoYrJlfQ3dyR.jpg',
#   'genres': 'Drama',
#   'production_countries': 'Mauritius',
#   'spoken_languages': 'French'},
#  {'_id': '65ef4285675dde80108f7d4b',
#   'id': 471965,
#   'title': 'Illustrated conversation with Professor Lars Kristiansson',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1985-02-08T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 123,
#   'adult': False,
#   'budget': 0,
#   'homepage': 'http://www.sfi.se/sv/svensk-filmdatabas/Item/?itemid=14713&type=MOVIE&iv=Basic',
#   'imdb_id': 'tt0089328',
#   'original_language': 'sv',
#   'original_title': 'Illustrerat samtal med professor Lars Kristiansson',
#   'overview': "Based on the conversations Jösta Hagelbäck and Erik Ostlund had with Lars Kristiansson, a professor of information theory with data communication at Chalmers University in Gothenburg, Sweden. The talks took place at the difficult cancer sufferer Kristiansson's sick-bed and dealt with his insights in computer technology, his hopes and fears for the new technology, the role of religion, the history of mathematics, reasoning about algebra, analytic geometry and the fourth dimension, along with cultural outlooks over the Western society's lack of mysticism and spiritual values.",
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//pWkGQUQIDCUegFAwNuPigpQplc6.jpg',
#   'genres': 'Documentary',
#   'production_companies': 'Svenska Filminstitutet',
#   'production_countries': 'Sweden',
#   'spoken_languages': 'Swedish'},
#  {'_id': '65ef43f8675dde801093d66c',
#   'id': 593893,
#   'title': 'MISS(ING)',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2018-09-21T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 21,
#   'adult': False,
#   'budget': 1500,
#   'imdb_id': 'tt9038288',
#   'original_language': 'es',
#   'original_title': 'MISS(ING)',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//t0vpopljhh9M6slmbNy7Ure8JbD.jpg',
#   'tagline': 'When a sex tape hits the net, Santino decides to find the responsible in order to protect and take revenge for who he loves the most.',
#   'genres': 'Thriller, Drama',
#   'production_countries': 'Peru',
#   'spoken_languages': 'Spanish'},
#  {'_id': '65ef417f675dde80108be1e6',
#   'id': 871358,
#   'title': 'Moon Monsoon',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2021-06-13T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 10,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'zh',
#   'original_title': '眠眠雨季',
#   'overview': 'If I lose you now. How to live my life? You just come to me. Let us start a brand new life.',
#   'popularity': 0.6,
#   'genres': 'Animation',
#   'production_countries': 'Taiwan'},
#  {'_id': '65ef4282675dde80108f7048',
#   'id': 486246,
#   'title': 'Maheruh',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Maheruh',
#   'overview': 'Maheruh is a Hindi movie starring Amit Dolawat and Drisha More in prominent roles. It is a drama directed by Vithal Sunita Veturkar.',
#   'popularity': 0.6},
#  {'_id': '65ef4245675dde80108eab8f',
#   'id': 1149579,
#   'title': 'Silence-Memories',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2014-12-20T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 26,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'th',
#   'original_title': 'ความทรงจำ-ไร้เสียง',
#   'overview': 'A short documentary telling the stories of two families whose children perished in the Thammasat University massacre',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//nODnR4QwB5EVoTqfENwQrWuxKyF.jpg',
#   'spoken_languages': 'Thai'},
#  {'_id': '65ef42c4675dde8010902bf1',
#   'id': 560048,
#   'title': 'The English Masters: Turner',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1996-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 50,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'The English Masters: Turner',
#   'overview': 'A Royal Academy exhibitioner at the age of fifteen, J.M.W. Turner, by the end of his life, was the best known artists in England during the Romantic period and one of the forerunners of Impressionism.  A life-long lover of landscape and seascape painting, he traveled widely in search of inspiration. No artist had ever painted light and color as Turner did in his astonishing later works. These paintings such as Rain, Steam, Speed and The Fighting Temerair were the conclusion to the long evolution of the art of J. M. W. Turner.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//uB7i7YUgVVxg6MSBkCB9gxTPuRD.jpg'},
#  {'_id': '65ef424d675dde80108ec600',
#   'id': 1140941,
#   'title': 'Tea',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2023-04-20T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 17,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'ar',
#   'original_title': 'شاي',
#   'overview': 'A new night-shift employee sets off for the apparently simple task of making himself a cup of tea.',
#   'popularity': 0.6,
#   'genres': 'Drama',
#   'production_countries': 'Egypt',
#   'spoken_languages': 'Arabic'},
#  {'_id': '65ef4036675dde801087e456',
#   'id': 679421,
#   'title': 'El Francotirador fenómeno',
#   'vote_average': 5,
#   'vote_count': 2,
#   'status': 'Released',
#   'release_date': '1989-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0246635',
#   'original_language': 'en',
#   'original_title': 'El Francotirador fenómeno',
#   'overview': 'Mexican feature film',
#   'popularity': 0.6,
#   'production_countries': 'Mexico'},
#  {'_id': '65ef4002675dde8010874ab3',
#   'id': 333783,
#   'title': 'Bullets for Jesus',
#   'vote_average': 3.5,
#   'vote_count': 4,
#   'status': 'Released',
#   'release_date': '2015-07-07T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt2315144',
#   'original_language': 'en',
#   'original_title': 'Bullets for Jesus',
#   'overview': 'A tense nonstop roller-coaster ride through the distorted mind of Sly Stone, a sadistic and brutal killer who distorts the scriptures to suit his own self serving madness. He\'s teamed up with a run-away drifter Annie Parker who bows to his every command... both for love and for fear of her own life. " I have the Bullets For Jesus " is Slys motto, and NO ONE is safe from his twisted pulpit.',
#   'popularity': 1.215,
#   'poster_path': 'https://image.tmdb.org/t/p/original//a1IbHS3F67yL0ennujVXjqTkmlG.jpg',
#   'spoken_languages': 'English'},
#  {'_id': '65ef3f57675dde801085810e',
#   'id': 487437,
#   'title': 'White as Snow',
#   'vote_average': 5.173,
#   'vote_count': 78,
#   'status': 'Released',
#   'release_date': '2019-04-10T00:00:00.000Z',
#   'revenue': 0,
# ...
#   'tagline': 'See Zombie. Kill Zombie. Be Zombie.',
#   'production_companies': 'Red Peak Pictures'},
#  {'_id': '65ef4333675dde801091738d',
#   'id': 372852,
#   'title': 'The Adventures of Miss Girl',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2007-02-14T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 50,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt2986938',
#   'original_language': 'en',
#   'original_title': 'The Adventures of Miss Girl',
#   'overview': 'Miss Girl moves to Chicago with her boyfriend and discovers a new world and a new identity.',
#   'popularity': 0.6,
#   'tagline': 'Once upon a time in Chicago there was a girl becoming a woman...',
#   'genres': 'Drama',
#   'production_companies': 'The Underground Multiplex',
#   'production_countries': 'United States of America'},
#  {'_id': '65ef3fcf675dde801086ba9f',
#   'id': 799861,
#   'title': 'The Boathouse',
#   'vote_average': 5.667,
#   'vote_count': 6,
#   'status': 'Released',
#   'release_date': '2021-08-12T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 90,
#   'adult': False,
#   'backdrop_path': '/5CIXxWUfMAAgHh8nKxeSznELMf1.jpg',
#   'budget': 0,
#   'imdb_id': 'tt13222298',
#   'original_language': 'en',
#   'original_title': 'The Boathouse',
#   'overview': "When an emotionally-fragile young woman takes a job as nanny to two troubled children at a remote summer cottage, she falls in love with the children's father, while becoming enmeshed in the mystery of their estranged mother - with whom, it turns out, the young woman has her own fraught history. As the summer progresses, she begins to suspect that the family has a dark history that they are desperate to keep secret.",
#   'popularity': 6.307,
#   'poster_path': 'https://image.tmdb.org/t/p/original//9TOsmFHavGOpvwvgPvPE3gmrvR6.jpg',
#   'tagline': "Who can you trust when you can't trust yourself?",
#   'genres': 'Mystery, Drama, Thriller',
#   'production_companies': 'Circle Blue Entertainment, Freddie Films, levelFILM, MarVista Entertainment',
#   'production_countries': 'Canada, United States of America',
#   'spoken_languages': 'English, French'},
#  {'_id': '65ef4072675dde8010887e27',
#   'id': 241458,
#   'title': 'Guns in the Dark',
#   'vote_average': 5.5,
#   'vote_count': 2,
#   'status': 'Released',
#   'release_date': '1937-05-13T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 56,
#   'adult': False,
#   'backdrop_path': '/8C9yKkKcTvFX1Sb67QPgq0Thhz7.jpg',
#   'budget': 0,
#   'imdb_id': 'tt0028969',
#   'original_language': 'en',
#   'original_title': 'Guns in the Dark',
#   'overview': 'When Johnny and Mendez argue, the lights go out, and in the ensuing gunfight Johnny thinks he killed his friend Dick. Now refusing to wear a gun he crosses the border. But it is not long before he runs into Mendez and more trouble.',
#   'popularity': 0.969,
#   'poster_path': 'https://image.tmdb.org/t/p/original//9JOWLdk6deHe32LRJVzE6pveUHL.jpg',
#   'tagline': 'Two shots in the dark...the flash of a deadly blade...and a man lies dead. Who is the killer?',
#   'genres': 'Western',
#   'production_companies': 'Supreme Pictures',
#   'production_countries': 'United States of America',
#   'spoken_languages': 'English'},
#  {'_id': '65ef438e675dde80109281d9',
#   'id': 738430,
#   'title': 'Experiencia Cumbre',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2020-08-06T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 85,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'es',
#   'original_title': 'Experiencia Cumbre',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//exOTUSgvOCst64p5p9nJR8CURPO.jpg',
#   'genres': 'Documentary',
#   'production_countries': 'Argentina',
#   'spoken_languages': 'Spanish'},
#  {'_id': '65ef409e675dde80108904fb',
#   'id': 969048,
#   'title': 'Halloween Jack 3D',
#   'vote_average': 7,
#   'vote_count': 1,
#   'status': 'Released',
#   'release_date': '2022-09-29T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 62,
#   'adult': False,
#   'budget': 0,
#   'homepage': 'https://www.livestreamtheatre.gumroad.com/',
#   'original_language': 'en',
#   'original_title': 'Halloween Jack 3D',
#   'overview': '10 years after the bloody murders by Halloween Jack at a holiday camp site, the three remaining survivors return to try and put their horrific past behind them...  But Jack has other plans for them, in gut wrenching 3D!',
#   'popularity': 1.4,
#   'poster_path': 'https://image.tmdb.org/t/p/original//2kOLo8MsM33G0TPg6rIw9hS0hjW.jpg',
#   'genres': 'Horror',
#   'production_companies': 'Live-Stream Theatre, PieOnEarring Films',
#   'production_countries': 'United Kingdom',
#   'spoken_languages': 'English'},
#  {'_id': '65ef43ab675dde801092e32a',
#   'id': 795184,
#   'title': 'The Meeting',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1989-05-03T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 74,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0405515',
#   'original_language': 'en',
#   'original_title': 'The Meeting',
#   'overview': "Fictional meeting between Dr. Martin Luther King and Malcolm X in Harlem in the early '60's.",
#   'popularity': 0.875,
#   'poster_path': 'https://image.tmdb.org/t/p/original//xc2AqTwYQ5CglaP3u11cNhM8e4B.jpg',
#   'genres': 'Drama'},
#  {'_id': '65ef3fbc675dde8010868728',
#   'id': 272270,
#   'title': 'Canaan',
#   'vote_average': 6.1,
#   'vote_count': 8,
#   'status': 'Released',
#   'release_date': '2008-10-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 100,
#   'adult': False,
#   'backdrop_path': '/8WTTVBoOzfxobBvdxK0pvtx4GmA.jpg',
#   'budget': 0,
#   'imdb_id': 'tt1283889',
#   'original_language': 'fa',
#   'original_title': 'کنعان',
#   'overview': 'Mina has decided to leave her older husband Morteza after ten years of marriage. Next Monday will be her divorce date, which means her first step towards her goal; immigration. However, the arrival of her older sister, Azar, together with the illness of her mother in law is causing her trouble. To her surprise, meanwhile, she finds out she is pregnant.',
#   'popularity': 1.572,
#   'poster_path': 'https://image.tmdb.org/t/p/original//3xKB0RhdH461KITOwuP10C1CnTG.jpg',
#   'genres': 'Drama',
#   'production_countries': 'Iran',
#   'spoken_languages': 'Persian'},
#  {'_id': '65ef41b1675dde80108c94fb',
#   'id': 1196428,
#   'title': 'Kate: Our New Diana?',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2023-07-15T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 45,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Kate: Our New Diana?',
#   'overview': 'Comparing the life and style of two Princesses of Wales: Kate and Diana.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//rsdoaihS7WXd7utdXOUhFVyNX3x.jpg',
#   'spoken_languages': 'English'},
#  {'_id': '65ef4427675dde8010946881',
#   'id': 678889,
#   'title': 'Ricky Glore: Dad Bod',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Ricky Glore: Dad Bod',
#   'overview': 'Ricky Glore is a stand up comedian and comedy writer known for his high energy and confidence on stage. He has opened for some of the top comedians, including Tracy Morgan, Damon Wayans, and Doug Benson. Whether he is discussing married life, family, pop culture or everyday observations, he is sure to be bringing a smile to your face and a laugh from your belly.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//mSM1dMMA4lBs8slolOl6hdgSSRo.jpg'},
#  {'_id': '65ef433b675dde80109189fd',
#   'id': 313542,
#   'title': 'The Man and the Snake',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1972-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 26,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0493273',
#   'original_language': 'en',
#   'original_title': 'The Man and the Snake',
#   'overview': 'A young man visits the house of a snake collector...horror ensues',
#   'popularity': 0.932,
#   'genres': 'Mystery, Horror',
#   'production_companies': 'Jocelyn Films',
#   'production_countries': 'United Kingdom'},
#  {'_id': '65ef423e675dde80108e965d',
#   'id': 1127937,
#   'title': 'Mr Billums',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2023-05-16T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 7,
#   'adult': False,
#   'backdrop_path': '/sXWeHMZNJLpxRxfMp7zzDvc1HSu.jpg',
#   'budget': 0,
#   'imdb_id': 'tt27791091',
#   'original_language': 'en',
#   'original_title': 'Mr Billums',
#   'overview': "A mysterious figure from Thomas's past returns to visit",
#   'popularity': 1.4,
#   'poster_path': 'https://image.tmdb.org/t/p/original//2rYP4CKdmAyXcxYlLaGo5jWiHOE.jpg',
#   'tagline': 'He always comes back',
#   'genres': 'Horror, Thriller',
#   'spoken_languages': 'English'},
#  {'_id': '65ef426c675dde80108f287f',
#   'id': 1115328,
#   'title': 'Eddie Loves You',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2006-01-01T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 26,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt15640184',
#   'original_language': 'en',
#   'original_title': 'Eddie Loves You',
#   'overview': 'A fluffy doll (of the type one usually tickles) stalks the person who abandoned him years ago.',
#   'popularity': 0.6,
#   'genres': 'Comedy, Horror',
#   'spoken_languages': 'English'},
#  {'_id': '65ef411f675dde80108a9779',
#   'id': 1001689,
#   'title': 'Badnaam',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1990-07-19T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 139,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt0363454',
#   'original_language': 'bn',
#   'original_title': 'বদনাম',
#   'overview': "Haranath is led to committing suicide due to the atrocities of Mathur Ghosh, an evil and corrupt man. However, Haranath's son, Shankar, grows up with the sole aim of avenging the wrongs done to his father.",
#   'popularity': 0.68,
#   'poster_path': 'https://image.tmdb.org/t/p/original//2rOnxu178oCi8Se1dZ2lLhYAQy8.jpg',
#   'production_countries': 'India'},
#  {'_id': '65ef41b6675dde80108ca596',
#   'id': 1197854,
#   'title': 'Make It Happen',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2023-01-06T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 5,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'th',
#   'original_title': 'Make It Happen',
#   'overview': "Rueang asks Oum to help him decide what to buy for Fah, Rueang's girlfriend. On his coming anniversary.",
#   'popularity': 1.165,
#   'poster_path': 'https://image.tmdb.org/t/p/original//5haNyh4wgJtNk1k1LW9ccqESkRD.jpg',
#   'tagline': "As friends, we still miss each other. But if we're lovers, we probably won't forget each other.",
#   'genres': 'Romance, Comedy',
#   'spoken_languages': 'Thai'},
#  {'_id': '65ef4208675dde80108ddbad',
#   'id': 1063929,
#   'title': 'FETAL',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'revenue': 0,
#   'runtime': 3,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'FETAL',
#   'overview': 'a film by Todd Verow starring Philly Abe.',
#   'popularity': 0.6},
#  {'_id': '65ef4226675dde80108e4543',
#   'id': 1034998,
#   'title': "New York's Worst Landlords",
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2021-06-07T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 71,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': "New York's Worst Landlords",
#   'overview': 'Jeff Seal spent three years tracking down the landlords on the annual Landlord’s Watchlist put out by New York City’s Public Advocate Office.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//gsIPrufMiXw6JwnHID8OuHv0xWN.jpg',
#   'genres': 'Documentary'},
#  {'_id': '65ef42ea675dde8010909cd2',
#   'id': 269782,
#   'title': 'Pinoy Pride XXII',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2013-10-26T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 0,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Pinoy Pride XXII',
#   'overview': 'Genesis Servania vs. Rafael Concepcion for the WBO Inter-Contnental Super Bantamweight championship.',
#   'popularity': 0.6,
#   'tagline': 'The revenge.',
#   'genres': 'Action',
#   'production_companies': 'ALA Promotions',
#   'production_countries': 'Philippines',
#   'spoken_languages': 'Tagalog, English'},
#  {'_id': '65ef441d675dde8010944a8e',
#   'id': 643541,
#   'title': 'Jeunes et courts!',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2019-11-27T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 73,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt11043910',
#   'original_language': 'fr',
#   'original_title': 'Jeunes et courts!',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//tgSVT0UEwUE6W4PvlqZtkjVOm94.jpg',
#   'genres': 'Drama, Comedy'},
#  {'_id': '65ef42ef675dde801090a847',
#   'id': 253035,
#   'title': 'Pixies: Live at Brixton Academy 1991',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '1991-11-30T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 81,
#   'adult': False,
#   'budget': 0,
#   'original_language': 'en',
#   'original_title': 'Pixies: Live at Brixton Academy 1991',
#   'overview': 'The Pixies live set at Brixton Academy in London on June 26, 1991.',
#   'popularity': 0.6,
#   'poster_path': 'https://image.tmdb.org/t/p/original//3mRdeCKJF0Vfr04GtsLJIKQRw4q.jpg',
#   'genres': 'Music',
#   'spoken_languages': 'English'},
#  {'_id': '65ef3fbb675dde801086823f',
#   'id': 175593,
#   'title': 'Down to the Sea in Ships',
#   'vote_average': 5.125,
#   'vote_count': 8,
#   'status': 'Released',
#   'release_date': '1922-11-21T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 94,
#   'adult': False,
#   'backdrop_path': '/nK9PThrF2ALfP9TnZz0MiYoMbmQ.jpg',
#   'budget': 0,
#   'imdb_id': 'tt0013085',
#   'original_language': 'en',
#   'original_title': 'Down to the Sea in Ships',
#   'overview': "Being the story of the Morgans, a 19th-century Massachusetts whaling family, their tightly-knit Quaker community, and the dangerous adventures of an unwilling stowaway aboard one of the elder Morgan's harvest vessels.",
#   'popularity': 1.423,
#   'poster_path': 'https://image.tmdb.org/t/p/original//rfYowYPTmnBrWD3SE0By0HZWYOL.jpg',
#   'genres': 'Adventure, Drama, Romance',
#   'production_countries': 'United States of America'},
#  {'_id': '65ef3f5b675dde80108587ab',
#   'id': 583841,
#   'title': 'Truth and Justice',
#   'vote_average': 7.654,
#   'vote_count': 68,
#   'status': 'Released',
#   'release_date': '2019-02-22T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 165,
#   'adult': False,
#   'backdrop_path': '/aF6ZNNt254abdvywjjvvRTf8DOn.jpg',
#   'budget': 2758542,
#   'homepage': 'http://allfilm.ee/et/projektid/tode-ja-oigus/',
#   'imdb_id': 'tt5593384',
#   'original_language': 'et',
#   'original_title': 'Tõde ja Õigus',
#   'overview': "Estonia, 1872. The uncompromising new owner of Robber's Rise must battle with hard work, his spiteful neighbor and with his own family and beliefs to transform the poor land into a flourishing farm of his dreams.",
#   'popularity': 7.285,
#   'poster_path': 'https://image.tmdb.org/t/p/original//l8HlPxCzyGz5sNXSNi6GbSKOgC9.jpg',
#   'tagline': 'How much shall you need to sacrifice for your dream?',
#   'genres': 'Drama, History',
#   'production_companies': 'Allfilm',
#   'production_countries': 'Estonia',
#   'spoken_languages': 'Estonian'},
#  {'_id': '65ef4362675dde801091f80a',
#   'id': 750862,
#   'title': 'Mystery Street: Murder at Harvard',
#   'vote_average': 0,
#   'vote_count': 0,
#   'status': 'Released',
#   'release_date': '2007-07-31T00:00:00.000Z',
#   'revenue': 0,
#   'runtime': 5,
#   'adult': False,
#   'budget': 0,
#   'imdb_id': 'tt1194148',
#   'original_language': 'en',
#   'original_title': 'Mystery Street: Murder at Harvard',
#   'overview': 'Presents testimony from Patricia King Hanson and Richard Schickel and archival input from cinematographer John Alton.',
#   'popularity': 0.6,
#   'production_companies': 'Time Warner'}]

# %%
response.status_code
# Out:
# 200

# %%
pelis = response.json()

# %%
len(pelis)
# Out:
# 1000

# %%
peliculas = {
    "titulo": [],
    "año_de_lanzamiento": [],
    "duracion": [],
    "genero": [],
    "contenido_para_adultos": [],
    "id_imdb": []
}
# Contador peliculas 
contador_peliculas = 0

# Bucle para hacer hasta 1000 llamadas y extraer datos
for i in range(1000):  # Intento obtener hasta 1000 películas
    if contador_peliculas < 10:  # Limito a 10 llamadas
        try:
            # Realizo la solicitud a la API
            response = requests.get(url, headers=headers)
            
            # Verifico si la respuesta es exitosa
            if response.status_code == 200:
                data = pelis
                
                # Extraigo los campos requeridos
                titulo = data.get('title', 'N/A')
                ano = data.get('releaseYear', 'N/A')
                duracion = data.get('runtime', 'N/A')
                genero = data['genres'][0] if data.get('genres') else 'N/A'
                adultos = "Sí" if data.get('adult', False) else "No"
                id_imdb = data.get('imdb_id', 'N/A')

                # Agrego los datos extraídos a las listas correspondientes en el diccionario
                peliculas["titulo"].append(titulo)
                peliculas["año_de_lanzamiento"].append(ano)
                peliculas["duracion"].append(duracion)
                peliculas["genero"].append(genero)
                peliculas["contenido_para_adultos"].append(adultos)
                peliculas["id_imdb"].append(id_imdb)

                # Incremento el contador de películas
                contador_peliculas += 1

            else:
                print(f"Error en la solicitud: {response.status_code}")

        except Exception as e:
            print(f"Error durante la extracción de datos: {e}")
# Out:
# Error durante la extracción de datos: 'list' object has no attribute 'get'
# Error durante la extracción de datos: 'list' object has no attribute 'get'
# Error durante la extracción de datos: 'list' object has no attribute 'get'
# Error durante la extracción de datos: 'list' object has no attribute 'get'
# Error durante la extracción de datos: 'list' object has no attribute 'get'
# Error durante la extracción de datos: 'list' object has no attribute 'get'
# Error durante la extracción de datos: 'list' object has no attribute 'get'
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# Error en la solicitud: 429
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 13>()
#      14 if contador_peliculas < 10:  # Limito a 10 llamadas
#      15     try:
#      16         # Realizo la solicitud a la API
# ---> 17         response = requests.get(url, headers=headers)
#      19         # Verifico si la respuesta es exitosa
#      20         if response.status_code == 200:
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1038 # Force connect early to allow us to validate the connection.
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#    1043     warnings.warn(
#    1044         (
#    1045             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1050         InsecureRequestWarning,
#    1051     )
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/anaconda3/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/anaconda3/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File ~/anaconda3/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Fase 2: Extracción de subtítulos

# %% [markdown]
# Con el `id_imdb` obtenido en la fase anterior, vamos a **extraer los subtítulos** de cada película utilizando una API diferente:
#
# - Enlace a la API: [MoviesDatabase API](https://rapidapi.com/SAdrian/api/moviesdatabase)
# - Endpoint a utilizar: `/titles/{id}` (donde `{id}` es el `id_imdb` extraído previamente)
#
# El objetivo en esta fase es obtener el subtítulo asociado a cada película. (caption)

# %% [markdown]
# ## Fase 3: Creación de DataFrames

# %% [markdown]
# Una vez que hayamos extraído los datos de ambas APIs, vamos a:
#
# 1. **Crear un DataFrame** con los datos de las películas.
# 2. **Crear un segundo DataFrame** con los subtítulos asociados a las películas.
#
# Para ello, vamos a utilizar la librería **Pandas**. Es necesario desarrollar funciones que almacenen los datos extraídos en un diccionario, para luego convertirlos en DataFrames.

# %% [markdown]
# ## Fase 4: Creación de la Base de Datos

# %% [markdown]
# En esta fase:
#
# 1. **Importamos las librerías necesarias** para crear una base de datos (como `mysql.connector` o `SQLAlchemy`).
# 2. **Automatizamos la creación de una base de datos** utilizando Python.
# 3. **Creamos las tablas en la base de datos** a partir de los DataFrames creados previamente.

# %% [markdown]
# ### Estructura de la Base de Datos:

# %% [markdown]
# - **Tabla de películas**:
#   - `id` (entero, `AUTO_INCREMENT`, clave primaria)
#   - `titulo` (texto)
#   - `anio_lanzamiento` (entero)
#   - `duracion` (entero, en minutos)
#   - `genero` (texto)
#   - `adulto` (booleano)
#   - `id_imdb` (texto)
#
# - **Tabla de subtítulos**:
#   - `id_imdb` (texto, clave primaria)
#   - `subtitulo` (texto)

# %% [markdown]
# ## Bonus - Inserción de los Datos en la Base de Datos

# %% [markdown]
# En este apartado adicional, vamos a realizar la inserción de los datos extraídos en las tablas creadas en nuestra base de datos MySQL.
